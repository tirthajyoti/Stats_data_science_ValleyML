# %% [markdown]
# # Basics of Matplotlib and Seaborn - data visualization with Python
# ### Dr. Tirthajyoti Sarkar, Fremont, CA 94536
# ---
# This notebook teaches the basics of two of the most popular visualization libraries in the Python universe - Matplotlib and Seaborn. We will show, how using minimal code, you can create various types of plots - scatterplot, boxplot, histogram, bar charts, etc.

# %% [markdown]
# ### Scatterplot - basic
# We start by defining some data. Let's suppose we collected age (in years), height (in cm), and weight (in lbs) information from few patients visitng a clinic.

# %%
people = ['Ann','Brandon','Chen','David','Emily','Farook',
          'Gagan','Hamish','Imran','Julio','Katherine','Lily']
age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]

# %% [markdown]
# We may ask ourselves, is there a relationship between these features? We can plot age. vs. height or height vs. weight with a minimal amount of code.

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(age, height)
plt.show()

# %% [markdown]
# ### Scatterplot - adding bells and whistles
#
# The plot above is OK but looks barebone. We can add few bells and whistles to it with simple code.
#
# * Figure size
# * Main title
# * X- and Y-labels
# * X- and Y-ticks
# * Grid
# * Text for labelling
# * Legend
# * Vertical (or horizontal) lines

# %%
# Set figure size
plt.figure(figsize=(8,6))

# Add a main title
plt.title("Plot of Age vs. Height (in cms)\n",fontsize=20, fontstyle='italic')

# X- and Y-label with fontsize
plt.xlabel("Age (years)",fontsize=16)
plt.ylabel("Height (cms)",fontsize=16)

# Turn on grid
plt.grid (True)

# Set Y-axis limit
plt.ylim(100,200)

# X- and Y-axis ticks customization with fontsize and placement
plt.xticks([i*5 for i in range(12)],fontsize=15)
plt.yticks(fontsize=15)

# Main plotting function with choice of color, marker size, and marker edge color
plt.scatter(x=age,y=height,c='orange',s=150,edgecolors='k')

# Adding bit of text to the plot
plt.text(x=15,y=105,s="Height increaes up to around \n20 years and then tapers off",fontsize=15, 
         rotation=30, linespacing=2)
plt.text(x=22,y=185,s="Nobody has a height beyond 180 cm",fontsize=15)

# Adding a vertical line
plt.vlines(x=20,ymin=100,ymax=180,linestyles='dashed',color='blue',lw=3)

# Adding a horizontal line
plt.hlines(y=180,xmin=0,xmax=55,linestyles='dashed',color='red',lw=3)

# Adding a legend
plt.legend(['Height in cms'],loc=2,fontsize=14)

# Final show method
plt.show()

# %% [markdown]
# ### Bar chart

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16, fontstyle='italic')
# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# ### Histogram

# %%
import numpy as np
heights = np.random.normal(loc=155,scale=10,size=100)
plt.figure(figsize=(7,5))
# Main plot function 'hist'
plt.hist(heights,color='red',edgecolor='k', alpha=0.75)
plt.title("Histogram of teen aged students' height",fontsize=18)
plt.xlabel("Height in cm",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Simple line plot

# %%
days = np.arange(1,31)
stock_A = 100+days*0.1+2*np.random.randn(30)
stock_B = 100-days*0.1+np.random.randn(30)

# %%
# Determine the minimum and maximum of stock prices
ymin = min(stock_A.min(),stock_B.min())
ymax = max(stock_A.max(),stock_B.max())

# %%
plt.rcParams['figure.facecolor'] = 'cyan'
plt.figure(figsize=(9,5))
plt.title("Time series plot of multiple stock prices\n",fontsize=20, fontstyle='italic')
plt.xlabel("Days",fontsize=16)
plt.ylabel("Stock price ($)",fontsize=16)
plt.grid (True)
plt.ylim(ymin*0.98,ymax*1.02)
plt.xticks([i*5 for i in range(12)],fontsize=15)
plt.yticks(fontsize=15)

# Main plotting function - plot (note markes)
plt.plot(days,stock_A,'o-',markersize=10,c='blue',lw=2)
plt.plot(days,stock_B,'^-',markersize=10,c='green',lw=2)

plt.legend(['Stock price of A ($)', 'Stock price of B ($)'],loc=2,fontsize=14)
plt.show()

# %% [markdown]
# ### Boxplot
